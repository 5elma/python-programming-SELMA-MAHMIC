# %%
paht = "Data/quotes.txt"

with open(path, "r") as f:
    text = f.read() # reads whole file

print(repr(text))

# %%
import re 

quotes, i = [], 1

with open(path, "r") as f_read, open("../Data/quotes_cleaned.txt", "w") as f_write:
    f_write("Famous quotes\n\n")
    for quote in f_read:
        quote = quote.strip(" \n")
        quote = re.sub(r" +", " ", quote) # substitute >1 whitespace with single whitespace
        if quote != "":
            f_write.write(f"{i}. {quote}\n")

# %%
with open("../Data/quotes_cleaned.txt", "r") as f_read, open("..Data/quotes_cleaned.txt", "a") as 
    quotes = [quote.strip("\n") for quote in f_read.readlines() if quote[0].isdigit()]
    authors = [quote.split()[-2:] for quote in quotes]
    authors = set([" ".join(author) for author in authors])
    print(authors)

    f_append.write("\nAuthors: ")
    for author in authors:
        f_append.write(f"{author}, ")

# %% [markdown]
# Polynom
#
# P[x] = kx**1 + m
#
# p = x+1, x, 2x+9
#
# P[x] = ax**2 + bx + 2
# x**2 - 2x+1
# x**2
#
# P[x] = bx**2 = cx + d
#
# kvadering/konjugat
#
# (x+y)**2 = x**2+2xy+y**2
# (x-4)**2 = x**2 - 2xy + y**2
# (x+y)(x-y) = x**2 + y**2
#
#
# faktorisering
#
# ax**2 + bx + c = 0
# x**2 - 2x + 1 = 0
# x = 1 +- **0.5 0
# x
#
# linjära ekvationssystem    kx + m
#
# 2x + 1 = y
# -x + 1 = y
#
#   substitution
#
#   2x + 1 = - x + 1
#   3x = 0
#
#   radoperation (additionsmetoden)
#
#   2x + 1 - ( - x + 1) = y - y
#   2x + 1 + x - 1 = 0
#   3x = 0
#
#   potenser och logaritmer
#
#   10**3   10 = bas    **3 = exponent
#
#   naturliga logoritmer ln e = 1
#
#   ln x**a = a * ln x
#   ln e = 1
#   ln e**a = a * lne = a
#   e**lna = a = lne**a
# ln(x * y) = lnx + lny  (e**a * e**b = e**a+b)
#
# ln (x/y) = lnx - 1ny  ln(1/x) = - x
#
# bevisföring
# "logiskt resonemang som leder till en viss slutsats"
#
# ex. pythagorasats
#
# (a + b)**2 = 2ab + c
# a**2 + b**2 = c**2
#
# en sekvens av operationer som leder till ett visst sluttillstånd
# algoritm, beivs, program
